# %%
# -*- coding: utf-8 -*-

from __future__ import absolute_import
from __future__ import division, print_function, unicode_literals

from sumyplus.parsers.parser import DocumentParser
from sumyplus.parsers.html import HtmlParser
from sumyplus.parsers.plaintext import PlaintextParser
from sumyplus.nlp.tokenizers import Tokenizer
from sumyplus.summarizers.lsa import LsaSummarizer as Summarizer
from sumyplus.nlp.stemmers import Stemmer
from sumyplus.utils import get_stop_words

# %%
LANGUAGE = "english"
SENTENCES_COUNT = 5

url = "https://en.wikipedia.org/wiki/Semantic_Web"
parser = HtmlParser.from_url(url, Tokenizer(LANGUAGE))

# or for plain text files
# parser = PlaintextParser.from_file("document.txt", Tokenizer(LANGUAGE))

stemmer = Stemmer(LANGUAGE)
summarizer = Summarizer(stemmer)
summarizer.stop_words = get_stop_words(LANGUAGE)

for sentence in summarizer(parser.document, SENTENCES_COUNT):
    print(sentence, '\n')
# Out:
# Compared to the public Semantic Web there are lesser requirements on scalability and the information circulating within a company can be more trusted in general; privacy is less of an issue outside of handling of customer data.
#
# Critics question the basic feasibility of a complete or even partial fulfillment of the Semantic Web, pointing out both difficulties in setting it up and a lack of general-purpose usefulness that prevents the required effort from being invested.
#
# […] cost-benefit tradeoffs can work in favor of specially-created Semantic Web metadata directed at weaving together sensible well-structured domain-specific information resources; close attention to user/customer needs will drive these federations if they are to be successful.
#
# Another argument in defense of the feasibility of semantic web is the likely falling price of human intelligence tasks in digital labor markets, such as Amazon 's Mechanical Turk .
#
# The GRDDL (Gleaning Resource Descriptions from Dialects of Language) mechanism allows existing material (including microformats) to be automatically interpreted as RDF, so publishers only need to use a single format, such as HTML.

# %%
from sumyplus.utils import get_stop_words

# %%
parser._article.main_text
# Out:
# [(('The', None),
#   ('Semantic Web', ('b',)),
#   ('is an extension of the', None),
#   ('World Wide Web', ('a',)),
#   ('through standards by the', None),
#   ('World Wide Web Consortium', ('a',)),
#   ('(W3C).', None),
#   ('[1]', ('a', 'sup')),
#   ('The standards promote common data formats and exchange protocols on the Web, most fundamentally the',
#    None),
#   ('Resource Description Framework', ('a',)),
#   ('(RDF). According to the W3C, "The Semantic Web provides a common framework that allows data to be shared and reused across application, enterprise, and community boundaries".',
#    None),
#   ('[2]', ('a', 'sup')),
#   ('The Semantic Web is therefore regarded as an integrator across different content, information applications and systems.',
#    None)),
#  (('The term was coined by', None),
#   ('Tim Berners-Lee', ('a',)),
#   ('for a web of data (or', None),
#   ('data web', ('b',)),
#   (')', None),
#   ('[3]', ('a', 'sup')),
#   ('that can be processed by machines', None),
#   ('[4]', ('a', 'sup')),
#   ('—that is, one in which much of the', None),
#   ('meaning', ('a',)),
#   ('is', None),
#   ('machine-readable', ('a',)),
#   ('. While its critics have questioned its feasibility, proponents argue that applications in industry, biology and human sciences research have already proven the validity of the original concept.',
#    None),
#   ('[5]', ('a', 'sup'))),
#  (('Berners-Lee originally expressed his vision of the Semantic Web as follows:',
#    None),),
#  (('I have a dream for the Web [in which computers] become capable of analyzing all the data on the Web – the content, links, and transactions between people and computers. A "Semantic Web", which makes this possible, has yet to emerge, but when it does, the day-to-day mechanisms of trade, bureaucracy and our daily lives will be handled by machines talking to machines. The "',
#    ('blockquote',)),
#   ('intelligent agents', ('a', 'blockquote')),
#   ('" people have touted for ages will finally materialize.', ('blockquote',)),
#   ('[6]', ('a', 'blockquote', 'sup'))),
#  (('The 2001', None),
#   ('Scientific American', ('a', 'i')),
#   ('article by Berners-Lee,', None),
#   ('Hendler', ('a',)),
#   (', and', None),
#   ('Lassila', ('a',)),
#   ('described an expected evolution of the existing Web to a Semantic Web.',
#    None),
#   ('[7]', ('a', 'sup')),
#   ('In 2006, Berners-Lee and colleagues stated that: "This simple idea…remains largely unrealized".',
#    None),
#   ('[8]', ('a', 'sup')),
#   ('In 2013, more than four million Web domains contained Semantic Web markup.',
#    None),
#   ('[9]', ('a', 'sup'))),
#  (('Example[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ("In the following example, the text 'Paul Schuster was born in Dresden' on a Website will be annotated, connecting a person with their place of birth. The following",
#    None),
#   ('HTML', ('a',)),
#   ('-fragment shows how a small graph is being described, in', None),
#   ('RDFa', ('a',)),
#   ('-syntax using a', None),
#   ('schema.org', ('a',)),
#   ('vocabulary and a', None),
#   ('Wikidata', ('a',)),
#   ('ID:', None)),
#  (('Graph resulting from the RDFa example', None),),
#  (('<divvocab="http://schema.org/"typeof="Person"><spanproperty="name">Paul Schuster</span> was born in\n<spanproperty="birthPlace"typeof="Place"href="http://www.wikidata.org/entity/Q1731"><spanproperty="name">Dresden</span>.\n</span></div>',
#    ('pre',)),),
#  (('The example defines the following five', None),
#   ('triples', ('a',)),
#   ('(shown in', None),
#   ('Turtle', ('a',)),
#   ('Syntax). Each triple represents one edge in the resulting graph: the first element of the triple (the',
#    None),
#   ('subject', ('i',)),
#   (') is the name of the node where the edge starts, the second element (the',
#    None),
#   ('predicate', ('i',)),
#   (') the type of the edge, and the last and third element (the', None),
#   ('object', ('i',)),
#   (') either the name of the node where the edge ends or a literal value (e.g. a text, a number, etc.).',
#    None)),
#  (('Graph resulting from the RDFa example, enriched with further data from the Web',
#    None),),
#  (('One of the advantages of using Uniform Resource Identifier (URIs) is that they can be dereferenced using the',
#    None),
#   ('HTTP', ('a',)),
#   ('protocol. According to the so-called', None),
#   ('Linked Open Data', ('a',)),
#   ('principles, such a dereferenced URI should result in a document that offers further data about the given URI. In this example, all URIs, both for edges and nodes (e.g.',
#    None),
#   ('http://schema.org/Person', ('tt',)),
#   (',', None),
#   ('http://schema.org/birthPlace', ('tt',)),
#   (',', None),
#   ('http://www.wikidata.org/entity/Q1731', ('tt',)),
#   (') can be dereferenced and will result in further RDF graphs, describing the URI, e.g. that Dresden is a city in Germany, or that a person, in the sense of that URI, can be fictional.',
#    None)),
#  (('The second graph shows the previous example, but now enriched with a few of the triples from the documents that result from dereferencing',
#    None),
#   ('http://schema.org/Person', ('tt',)),
#   ('(green edge) and', None),
#   ('http://www.wikidata.org/entity/Q1731', ('tt',)),
#   ('(blue edges).', None)),
#  (('Additionally to the edges given in the involved documents explicitly, edges can be automatically',
#    None),
#   ('inferred', ('a',)),
#   (': the triple', None)),
#  (('from the original RDFa fragment and the triple', None),),
#  (('from the document at', None),
#   ('http://schema.org/Person', ('tt',)),
#   ('(green edge in the Figure) allow to infer the following triple, given',
#    None),
#   ('OWL', ('a',)),
#   ('semantics (red dashed line in the second Figure):', None)),
#  (('Background[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ('The concept of the', None),
#   ('Semantic Network Model', ('a', 'i')),
#   ('was formed in the early 1960s by the cognitive scientist', None),
#   ('Allan M. Collins', ('a',)),
#   (', linguist', None),
#   ('M. Ross Quillian', ('a',)),
#   ('and psychologist', None),
#   ('Elizabeth F. Loftus', ('a',)),
#   ('as a form to represent semantically structured knowledge. When applied in the context of the modern internet, it extends the network of',
#    None),
#   ('hyperlinked', ('a',)),
#   ('human-readable', None),
#   ('web pages', ('a',)),
#   ('by inserting machine-readable', None),
#   ('metadata', ('a',)),
#   ('about pages and how they are related to each other. This enables automated agents to access the Web more intelligently and perform more tasks on behalf of users. The term "Semantic Web" was coined by',
#    None),
#   ('Tim Berners-Lee', ('a',)),
#   (',', None),
#   ('[4]', ('a', 'sup')),
#   ('the inventor of the World Wide Web and director of the', None),
#   ('World Wide Web Consortium', ('a',)),
#   ('("', None),
#   ('W3C', ('a',)),
#   ('"), which oversees the development of proposed Semantic Web standards. He defines the Semantic Web as "a web of data that can be processed directly and indirectly by machines".',
#    None)),
#  (('Many of the technologies proposed by the W3C already existed before they were positioned under the W3C umbrella. These are used in various contexts, particularly those dealing with information that encompasses a limited and defined domain, and where sharing data is a common necessity, such as scientific research or data exchange among businesses. In addition, other technologies with similar goals have emerged, such as',
#    None),
#   ('microformats', ('a',)),
#   ('.', None)),
#  (('Limitations of HTML[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ('Many files on a typical computer can also be loosely divided into human readable',
#    None),
#   ('documents', ('a',)),
#   ('and machine readable', None),
#   ('data', ('a',)),
#   ('. Documents like mail messages, reports, and brochures are read by humans. Data, such as calendars, addressbooks, playlists, and spreadsheets are presented using an application program that lets them be viewed, searched and combined.',
#    None)),
#  (('Currently, the World Wide Web is based mainly on documents written in',
#    None),
#   ('Hypertext Markup Language', ('a',)),
#   ('(', None),
#   ('HTML', ('a',)),
#   ('), a markup convention that is used for coding a body of text interspersed with multimedia objects such as images and interactive forms. Metadata tags provide a method by which computers can categorise the content of web pages, for example:',
#    None)),
#  (('<metaname="keywords"content="computing, computer studies, computer"/><metaname="description"content="Cheap widgets for sale"/><metaname="author"content="John Doe"/>',
#    ('pre',)),),
#  (('With HTML and a tool to render it (perhaps', None),
#   ('web browser', ('a',)),
#   ('software, perhaps another', None),
#   ('user agent', ('a',)),
#   ('), one can create and present a page that lists items for sale. The HTML of this catalog page can make simple, document-level assertions such as "this document\'s title is \'Widget Superstore\'", but there is no capability within the HTML itself to assert unambiguously that, for example, item number X586172 is an Acme Gizmo with a retail price of €199, or that it is a consumer product. Rather, HTML can only say that the span of text "X586172" is something that should be positioned near "Acme Gizmo" and "€199", etc. There is no way to say "this is a catalog" or even to establish that "Acme Gizmo" is a kind of title or that "€199" is a price. There is also no way to express that these pieces of information are bound together in describing a discrete item, distinct from other items perhaps listed on the page.',
#    None)),
#  (('Semantic HTML', ('a',)),
#   ('refers to the traditional HTML practice of markup following intention, rather than specifying layout details directly. For example, the use of',
#    None),
#   ('<em>', ('code',)),
#   ('denoting "emphasis" rather than', None),
#   ('<i>', ('code',)),
#   (', which specifies', None),
#   ('italics', ('a',)),
#   ('. Layout details are left up to the browser, in combination with', None),
#   ('Cascading Style Sheets', ('a',)),
#   ('. But this practice falls short of specifying the semantics of objects such as items for sale or prices.',
#    None)),
#  (('Semantic Web solutions[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ('The Semantic Web takes the solution further. It involves publishing in languages specifically designed for data:',
#    None),
#   ('Resource Description Framework', ('a',)),
#   ('(RDF),', None),
#   ('Web Ontology Language', ('a',)),
#   ('(OWL), and Extensible Markup Language (', None),
#   ('XML', ('a',)),
#   ('). HTML describes documents and the links between them. RDF, OWL, and XML, by contrast, can describe arbitrary things such as people, meetings, or airplane parts.',
#    None)),
#  (('These technologies are combined in order to provide descriptions that supplement or replace the content of Web documents. Thus, content may manifest itself as descriptive data stored in Web-accessible',
#    None),
#   ('databases', ('a',)),
#   (',', None),
#   ('[11]', ('a', 'sup')),
#   ('or as markup within documents (particularly, in Extensible HTML (', None),
#   ('XHTML', ('a',)),
#   (') interspersed with XML, or, more often, purely in XML, with layout or rendering cues stored separately). The machine-readable descriptions enable content managers to add meaning to the content, i.e., to describe the structure of the knowledge we have about that content. In this way, a machine can process knowledge itself, instead of text, using processes similar to human',
#    None),
#   ('deductive reasoning', ('a',)),
#   ('and', None),
#   ('inference', ('a',)),
#   (', thereby obtaining more meaningful results and helping computers to perform automated information gathering and research.',
#    None)),
#  (('An example of a tag that would be used in a non-semantic web page:',
#    None),),
#  (('Encoding similar information in a semantic web page might look like this:',
#    None),),
#  (('<itemrdf:about="http://example.org/semantic-web/">Semantic Web</item>',
#    ('pre',)),),
#  (('Tim Berners-Lee calls the resulting network of', None),
#   ('Linked Data', ('a',)),
#   ('the', None),
#   ('Giant Global Graph', ('a',)),
#   (', in contrast to the HTML-based', None),
#   ('World Wide Web', ('a',)),
#   ('. Berners-Lee posits that if the past was document sharing, the future is data sharing. His answer to the question of "how" provides three points of instruction. One, a URL should point to the data. Two, anyone accessing the URL should get data back. Three, relationships in the data should point to additional URLs with data.',
#    None)),
#  (('Web 3.0[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ("People keep asking what Web 3.0 is. I think maybe when you've got an overlay of",
#    ('blockquote',)),
#   ('scalable vector graphics', ('a', 'blockquote')),
#   ('– everything rippling and folding and looking misty – on',
#    ('blockquote',)),
#   ('Web 2.0', ('a', 'blockquote')),
#   ("and access to a semantic Web integrated across a huge space of data, you'll have access to an unbelievable data resource …",
#    ('blockquote',))),
#  (('"Semantic Web" is sometimes used as a synonym for "Web 3.0",', None),
#   ('[13]', ('a', 'sup')),
#   ('though the definition of each term varies. Web 3.0 has started to emerge as a movement away from the',
#    None),
#   ('centralisation', ('a',)),
#   ('of services like search, social media and chat applications that are dependent on a single organisation to function.',
#    None),
#   ('[14]', ('a', 'sup'))),
#  (('Challenges[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ('Some of the challenges for the Semantic Web include vastness, vagueness, uncertainty, inconsistency, and deceit.',
#    None),
#   ('Automated reasoning systems', ('a',)),
#   ('will have to deal with all of these issues in order to deliver on the promise of the Semantic Web.',
#    None)),
#  (('Vastness: The World Wide Web contains many billions of pages. The',
#    ('li', 'ul')),
#   ('SNOMED CT', ('a', 'li', 'ul')),
#   ('medical terminology', ('li', 'ul')),
#   ('ontology', ('a', 'li', 'ul')),
#   ('alone contains 370,000 class names, and existing technology has not yet been able to eliminate all semantically duplicated terms. Any automated reasoning system will have to deal with truly huge inputs.',
#    ('li', 'ul')),
#   ('Vagueness: These are imprecise concepts like "young" or "tall". This arises from the vagueness of user queries, of concepts represented by content providers, of matching query terms to provider terms and of trying to combine different knowledge bases with overlapping but subtly different concepts.',
#    ('li', 'ul')),
#   ('Fuzzy logic', ('a', 'li', 'ul')),
#   ('is the most common technique for dealing with vagueness.', ('li', 'ul')),
#   ('Uncertainty: These are precise concepts with uncertain values. For example, a patient might present a set of symptoms that correspond to a number of different distinct diagnoses each with a different probability.',
#    ('li', 'ul')),
#   ('Probabilistic', ('a', 'li', 'ul')),
#   ('reasoning techniques are generally employed to address uncertainty.',
#    ('li', 'ul')),
#   ('Inconsistency: These are logical contradictions that will inevitably arise during the development of large ontologies, and when ontologies from separate sources are combined.',
#    ('li', 'ul')),
#   ('Deductive reasoning', ('a', 'li', 'ul')),
#   ('fails catastrophically when faced with inconsistency, because',
#    ('li', 'ul')),
#   ('"anything follows from a contradiction"', ('a', 'li', 'ul')),
#   ('.', ('li', 'ul')),
#   ('Defeasible reasoning', ('a', 'li', 'ul')),
#   ('and', ('li', 'ul')),
#   ('paraconsistent reasoning', ('a', 'li', 'ul')),
#   ('are two techniques that can be employed to deal with inconsistency.',
#    ('li', 'ul')),
#   ('Deceit: This is when the producer of the information is intentionally misleading the consumer of the information.',
#    ('li', 'ul')),
#   ('Cryptography', ('a', 'li', 'ul')),
#   ("techniques are currently utilized to alleviate this threat. By providing a means to determine the information's integrity, including that which relates to the identity of the entity that produced or published the information, however",
#    ('li', 'ul')),
#   ('credibility', ('a', 'li', 'ul')),
#   ('issues still have to be addressed in cases of potential deceit.',
#    ('li', 'ul'))),
#  (('This list of challenges is illustrative rather than exhaustive, and it focuses on the challenges to the "unifying logic" and "proof" layers of the Semantic Web. The',
#    None),
#   ('World Wide Web Consortium', ('a',)),
#   ('(W3C) Incubator Group for Uncertainty Reasoning for the World Wide Web (URW3-XG)',
#    None),
#   ('final report', ('a',)),
#   ('lumps these problems together under the single heading of "uncertainty". Many of the techniques mentioned here will require extensions to the Web Ontology Language (OWL) for example to annotate conditional probabilities. This is an area of active research.',
#    None),
#   ('[15]', ('a', 'sup'))),
#  (('Standards[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ('Standardization for Semantic Web in the context of Web 3.0 is under the care of W3C.',
#    None),
#   ('[16]', ('a', 'sup'))),
#  (('Components[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ('The term "Semantic Web" is often used more specifically to refer to the formats and technologies that enable it.',
#    None),
#   ('[2]', ('a', 'sup')),
#   ('The collection, structuring and recovery of linked data are enabled by technologies that provide a',
#    None),
#   ('formal description', ('a',)),
#   ('of concepts, terms, and relationships within a given', None),
#   ('knowledge domain', ('a',)),
#   ('. These technologies are specified as W3C standards and include:', None)),
#  (('The', None),
#   ('Semantic Web Stack', ('a',)),
#   ('illustrates the architecture of the Semantic Web. The functions and relationships of the components can be summarized as follows:',
#    None),
#   ('[17]', ('a', 'sup'))),
#  (('XML provides an elemental syntax for content structure within documents, yet associates no semantics with the meaning of the content contained within. XML is not at present a necessary component of Semantic Web technologies in most cases, as alternative syntaxes exists, such as',
#    ('li', 'ul')),
#   ('Turtle', ('a', 'li', 'ul')),
#   ('. Turtle is a de facto standard, but has not been through a formal standardization process.',
#    ('li', 'ul')),
#   ('XML Schema', ('a', 'li', 'ul')),
#   ('is a language for providing and restricting the structure and content of elements contained within XML documents.',
#    ('li', 'ul')),
#   ('RDF is a simple language for expressing', ('li', 'ul')),
#   ('data models', ('a', 'li', 'ul')),
#   (', which refer to objects ("', ('li', 'ul')),
#   ('web resources', ('a', 'li', 'ul')),
#   ('") and their relationships. An RDF-based model can be represented in a variety of syntaxes, e.g., RDF/XML, N3, Turtle, and RDFa. RDF is a fundamental standard of the Semantic Web.',
#    ('li', 'ul')),
#   ('[18]', ('a', 'li', 'sup', 'ul')),
#   ('[19]', ('a', 'li', 'sup', 'ul')),
#   ('RDF Schema extends RDF and is a vocabulary for describing properties and classes of RDF-based resources, with semantics for generalized-hierarchies of such properties and classes.',
#    ('li', 'ul')),
#   ('OWL adds more vocabulary for describing properties and classes: among others, relations between classes (e.g. disjointness), cardinality (e.g. "exactly one"), equality, richer typing of properties, characteristics of properties (e.g. symmetry), and enumerated classes.',
#    ('li', 'ul')),
#   ('SPARQL is a protocol and query language for semantic web data sources.',
#    ('li', 'ul')),
#   ("RIF is the W3C Rule Interchange Format. It's an XML language for expressing Web rules that computers can execute. RIF provides multiple versions, called dialects. It includes a RIF Basic Logic Dialect (RIF-BLD) and RIF Production Rules Dialect (RIF PRD).",
#    ('li', 'ul'))),
#  (('Current state of standardization[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ('Well-established standards:', None)),
#  (('Applications[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ('Servers that expose existing data systems using the RDF and SPARQL standards. Many',
#    ('li', 'ul')),
#   ('converters to RDF', ('a', 'li', 'ul')),
#   ('exist from different applications.', ('li', 'ul')),
#   ('Relational databases', ('a', 'li', 'ul')),
#   ('are an important source. The semantic web server attaches to the existing system without affecting its operation.',
#    ('li', 'ul')),
#   ('Documents "marked up" with semantic information (an', ('li', 'ul')),
#   ('extension', ('a', 'li', 'ul')),
#   ('of the HTML', ('li', 'ul')),
#   ('<meta>', ('li', 'tt', 'ul')),
#   ('tags', ('a', 'li', 'ul')),
#   ("used in today's Web pages to supply information for", ('li', 'ul')),
#   ('Web search engines', ('a', 'li', 'ul')),
#   ('using', ('li', 'ul')),
#   ('web crawlers', ('a', 'li', 'ul')),
#   ('). This could be', ('li', 'ul')),
#   ('machine-understandable', ('a', 'li', 'ul')),
#   ('information about the human-understandable content of the document (such as the creator, title, description, etc.) or it could be purely',
#    ('li', 'ul')),
#   ('metadata', ('a', 'li', 'ul')),
#   ('representing a set of facts (such as resources and services elsewhere on the site). Note that',
#    ('li', 'ul')),
#   ('anything', ('i', 'li', 'ul')),
#   ('that can be identified with a', ('li', 'ul')),
#   ('Uniform Resource Identifier', ('i', 'li', 'ul')),
#   ('(URI) can be described, so the semantic web can reason about animals, people, places, ideas, etc. There are four semantic annotation formats that can be used in HTML documents;',
#    ('li', 'ul')),
#   ('Microformat', ('a', 'li', 'ul')),
#   (',', ('li', 'ul')),
#   ('RDFa', ('a', 'li', 'ul')),
#   (',', ('li', 'ul')),
#   ('Microdata', ('a', 'li', 'ul')),
#   ('and', ('li', 'ul')),
#   ('JSON-LD', ('a', 'li', 'ul')),
#   ('.', ('li', 'ul')),
#   ('[20]', ('a', 'li', 'sup', 'ul')),
#   ('Semantic markup is often generated automatically, rather than manually.',
#    ('li', 'ul')),
#   ('Common metadata vocabularies (', ('li', 'ul')),
#   ('ontologies', ('a', 'li', 'ul')),
#   (') and maps between vocabularies that allow document creators to know how to mark up their documents so that agents can use the information in the supplied metadata (so that',
#    ('li', 'ul')),
#   ('Author', ('i', 'li', 'ul')),
#   ("in the sense of 'the Author of the page' won't be confused with",
#    ('li', 'ul')),
#   ('Author', ('i', 'li', 'ul')),
#   ('in the sense of a book that is the subject of a book review).',
#    ('li', 'ul')),
#   ('Automated agents to perform tasks for users of the semantic web using this data.',
#    ('li', 'ul')),
#   ('Web-based services (often with agents of their own) to supply information specifically to agents, for example, a',
#    ('li', 'ul')),
#   ('Trust service', ('a', 'li', 'ul')),
#   ('that an agent could ask if some online store has a history of poor service or',
#    ('li', 'ul')),
#   ('spamming', ('a', 'li', 'ul')),
#   ('.', ('li', 'ul'))),
#  (('Such services could be useful to public search engines, or could be used for',
#    None),
#   ('knowledge management', ('a',)),
#   ('within an organization. Business applications include:', None)),
#  (('Facilitating the integration of information from mixed sources',
#    ('li', 'ul')),
#   ('Dissolving ambiguities in corporate terminology', ('li', 'ul')),
#   ('Improving', ('li', 'ul')),
#   ('information retrieval', ('a', 'li', 'ul')),
#   ('thereby reducing information overload and increasing the refinement and precision of the data retrieved',
#    ('li', 'ul')),
#   ('[21]', ('a', 'li', 'sup', 'ul')),
#   ('[22]', ('a', 'li', 'sup', 'ul')),
#   ('[23]', ('a', 'li', 'sup', 'ul')),
#   ('[24]', ('a', 'li', 'sup', 'ul')),
#   ('Identifying relevant information with respect to a given domain',
#    ('li', 'ul')),
#   ('[25]', ('a', 'li', 'sup', 'ul')),
#   ('Providing decision making support', ('li', 'ul'))),
#  (('In a corporation, there is a closed group of users and the management is able to enforce company guidelines like the adoption of specific',
#    None),
#   ('ontologies', ('a',)),
#   ('and use of', None),
#   ('semantic annotation', ('a',)),
#   ('. Compared to the public Semantic Web there are lesser requirements on',
#    None),
#   ('scalability', ('a',)),
#   ('and the information circulating within a company can be more trusted in general; privacy is less of an issue outside of handling of customer data.',
#    None)),
#  (('Skeptical reactions[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ('Practical feasibility[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ('Critics question the basic feasibility of a complete or even partial fulfillment of the Semantic Web, pointing out both difficulties in setting it up and a lack of general-purpose usefulness that prevents the required effort from being invested. In a 2003 paper, Marshall and Shipman point out the cognitive overhead inherent in formalizing knowledge, compared to the authoring of traditional web',
#    None),
#   ('hypertext', ('a',)),
#   (':', None),
#   ('[26]', ('a', 'sup'))),
#  (('While learning the basics of HTML is relatively straightforward, learning a knowledge representation language or tool requires the author to learn about the representation\'s methods of abstraction and their effect on reasoning. For example, understanding the class-instance relationship, or the superclass-subclass relationship, is more than understanding that one concept is a “type of” another concept. […] These abstractions are taught to computer scientists generally and knowledge engineers specifically but do not match the similar natural language meaning of being a "type of" something. Effective use of such a formal representation requires the author to become a skilled knowledge engineer in addition to any other skills required by the domain. […] Once one has learned a formal representation language, it is still often much more effort to express ideas in that representation than in a less formal representation […]. Indeed, this is a form of programming based on the declaration of semantic data and requires an understanding of how reasoning algorithms will interpret the authored structures.',
#    ('blockquote',)),),
#  (('According to Marshall and Shipman, the', None),
#   ('tacit', ('a',)),
#   ("and changing nature of much knowledge adds to the knowledge engineering problem, and limits the Semantic Web's applicability to specific domains. A further issue that they point out are domain- or organisation-specific ways to express knowledge, which must be solved through community agreement rather than only technical means.",
#    None),
#   ('[26]', ('a', 'sup')),
#   ('As it turns out, specialized communities and organizations for intra-company projects have tended to adopt semantic web technologies greater than peripheral and less-specialized communities.',
#    None),
#   ('[27]', ('a', 'sup')),
#   ('The practical constraints toward adoption have appeared less challenging where domain and scope is more limited than that of the general public and the World-Wide Web.',
#    None),
#   ('[27]', ('a', 'sup'))),
#  (('Finally, Marshall and Shipman see pragmatic problems in the idea of (',
#    None),
#   ('Knowledge Navigator', ('a',)),
#   ('-style) intelligent agents working in the largely manually curated Semantic Web:',
#    None),
#   ('[26]', ('a', 'sup'))),
#  (('In situations in which user needs are known and distributed information resources are well described, this approach can be highly effective; in situations that are not foreseen and that bring together an unanticipated array of information resources, the Google approach is more robust. Furthermore, the Semantic Web relies on inference chains that are more brittle; a missing element of the chain results in a failure to perform the desired action, while the human can supply missing pieces in a more Google-like approach. […] cost-benefit tradeoffs can work in favor of specially-created Semantic Web metadata directed at weaving together sensible well-structured domain-specific information resources; close attention to user/customer needs will drive these federations if they are to be successful.',
#    ('blockquote',)),),
#  (('Cory Doctorow', ('a',)),
#   ('\'s critique ("', None),
#   ('metacrap', ('a',)),
#   ('") is from the perspective of human behavior and personal preferences. For example, people may include spurious metadata into Web pages in an attempt to mislead Semantic Web engines that naively assume the metadata\'s veracity. This phenomenon was well-known with metatags that fooled the',
#    None),
#   ('Altavista', ('a',)),
#   ('ranking algorithm into elevating the ranking of certain Web pages: the Google indexing engine specifically looks for such attempts at manipulation.',
#    None),
#   ('Peter Gärdenfors', ('a',)),
#   ('and', None),
#   ('Timo Honkela', ('a',)),
#   ('point out that logic-based semantic web technologies cover only a fraction of the relevant phenomena related to semantics.',
#    None),
#   ('[28][29]', ('a', 'sup'))),
#  (('Censorship and privacy[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ('Enthusiasm about the semantic web could be tempered by concerns regarding',
#    None),
#   ('censorship', ('a',)),
#   ('and', None),
#   ('privacy', ('a',)),
#   ('. For instance,', None),
#   ('text-analyzing', ('a',)),
#   ('techniques can now be easily bypassed by using other words, metaphors for instance, or by using images in place of words. An advanced implementation of the semantic web would make it much easier for governments to control the viewing and creation of online information, as this information would be much easier for an automated content-blocking machine to understand. In addition, the issue has also been raised that, with the use of',
#    None),
#   ('FOAF', ('a',)),
#   ('files and geolocation', None),
#   ('meta-data', ('a',)),
#   (', there would be very little anonymity associated with the authorship of articles on things such as a personal blog. Some of these concerns were addressed in the "Policy Aware Web" project',
#    None),
#   ('[30]', ('a', 'sup')),
#   ('and is an active research and development topic.', None)),
#  (('Doubling output formats[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ('Another criticism of the semantic web is that it would be much more time-consuming to create and publish content because there would need to be two formats for one piece of data: one for human viewing and one for machines. However, many',
#    None),
#   ('web applications', ('a',)),
#   ('in development are addressing this issue by creating a machine-readable format upon the publishing of data or the request of a machine for such data. The development of',
#    None),
#   ('microformats', ('a',)),
#   ('has been one reaction to this kind of criticism. Another argument in defense of the feasibility of semantic web is the likely falling price of human intelligence tasks in digital labor markets, such as',
#    None),
#   ('Amazon', ('a',)),
#   ("'s", None),
#   ('Mechanical Turk', ('a',)),
#   ('.', None),
#   ('[', ('sup',)),
#   ('citation needed', ('a', 'i', 'sup')),
#   (']', ('sup',))),
#  (('Specifications such as', None),
#   ('eRDF', ('a',)),
#   ('and', None),
#   ('RDFa', ('a',)),
#   ('allow arbitrary RDF data to be embedded in HTML pages. The', None),
#   ('GRDDL', ('a',)),
#   ('(Gleaning Resource Descriptions from Dialects of Language) mechanism allows existing material (including microformats) to be automatically interpreted as RDF, so publishers only need to use a single format, such as HTML.',
#    None)),
#  (('Research activities on corporate applications[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ('Since 2008, the Corporate Semantic Web research group, located at the',
#    None),
#   ('Free University of Berlin', ('a',)),
#   (', focuses on building blocks: Corporate Semantic Search, Corporate Semantic Collaboration, and Corporate Ontology Engineering.',
#    None),
#   ('[32]', ('a', 'sup'))),
#  (('Ontology engineering research includes the question of how to involve non-expert users in creating ontologies and semantically annotated content',
#    None),
#   ('[33]', ('a', 'sup')),
#   ('and for extracting explicit knowledge from the interaction of users within enterprises.',
#    None)),
#  (('Future of applications[', ('h3',)),
#   ('edit', ('a', 'h3')),
#   (']', ('h3',)),
#   ("Tim O'Reilly", ('a',)),
#   (', who coined the term', None),
#   ('Web 2.0', ('a',)),
#   ('proposed a long-term vision of the Semantic Web as a web of data, where sophisticated applications manipulate the data web.',
#    None),
#   ('[34]', ('a', 'sup')),
#   ('The data web transforms the', None),
#   ('Web', ('a',)),
#   ('from a', None),
#   ('distributedfile system', ('a',)),
#   ('into a distributed database system.', None),
#   ('[35]', ('a', 'sup'))),
#  (('See also[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']References[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('"XML and Semantic Web W3C Standards Timeline"', ('a', 'cite', 'li', 'ol')),
#   ('(PDF)', ('cite', 'li', 'ol')),
#   ('. 2012-02-04.', ('cite', 'li', 'ol')),
#   ('^', ('li', 'ol')),
#   ('a', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('b', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('"W3C Semantic Web Activity"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('World Wide Web Consortium', ('a', 'cite', 'li', 'ol')),
#   ('(W3C). November 7, 2011. Retrieved', ('cite', 'li', 'ol')),
#   ('November 26,', ('cite', 'li', 'ol')),
#   ('2011.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('"Q&A with Tim Berners-Lee, Special Report"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('businessweek.com', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('14 April', ('cite', 'li', 'ol')),
#   ('2018.', ('cite', 'li', 'ol')),
#   ('^', ('li', 'ol')),
#   ('a', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('b', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('Berners-Lee, Tim; James Hendler; Ora Lassila (May 17, 2001).',
#    ('cite', 'li', 'ol')),
#   ('"The Semantic Web"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('Scientific American', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('March 26,', ('cite', 'li', 'ol')),
#   ('2008.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Lee Feigenbaum (May 1, 2007).', ('cite', 'li', 'ol')),
#   ('"The Semantic Web in Action"', ('a', 'cite', 'li', 'ol')),
#   ('. Scientific American. Retrieved', ('cite', 'li', 'ol')),
#   ('February 24,', ('cite', 'li', 'ol')),
#   ('2010.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Berners-Lee, Tim', ('a', 'cite', 'li', 'ol')),
#   ('; Fischetti, Mark (1999).', ('cite', 'li', 'ol')),
#   ('Weaving the Web', ('a', 'cite', 'i', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('HarperSanFrancisco', ('a', 'cite', 'li', 'ol')),
#   ('. chapter 12.', ('cite', 'li', 'ol')),
#   ('ISBN', ('a', 'cite', 'li', 'ol')),
#   ('978-0-06-251587-2', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Berners-Lee, Tim (May 17, 2001).', ('cite', 'li', 'ol')),
#   ('"The Semantic Web"', ('a', 'cite', 'li', 'ol')),
#   ('(PDF)', ('cite', 'li', 'ol')),
#   ('. Scientific American. Retrieved', ('cite', 'li', 'ol')),
#   ('March 13,', ('cite', 'li', 'ol')),
#   ('2008.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Nigel Shadbolt; Wendy Hall; Tim Berners-Lee (2006).',
#    ('cite', 'li', 'ol')),
#   ('"The Semantic Web Revisited"', ('a', 'cite', 'li', 'ol')),
#   ('(PDF)', ('cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('IEEE', ('a', 'cite', 'i', 'li', 'ol')),
#   ('Intelligent Systems', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('April 13,', ('cite', 'li', 'ol')),
#   ('2007.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Ramanathan V. Guha (2013).', ('cite', 'li', 'ol')),
#   ('"Light at the End of the Tunnel"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('International Semantic Web Conference', ('a', 'cite', 'i', 'li', 'ol')),
#   ('2013 Keynote', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('March 8,', ('cite', 'li', 'ol')),
#   ('2015.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Allsopp, John (March 2007).', ('cite', 'li', 'ol')),
#   ('Microformats: Empowering Your Markup for Web 2.0',
#    ('cite', 'i', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('Friends of ED', ('a', 'cite', 'li', 'ol')),
#   ('. p. 368.', ('cite', 'li', 'ol')),
#   ('ISBN', ('a', 'cite', 'li', 'ol')),
#   ('978-1-59059-814-6', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Artem Chebotko and Shiyong Lu, "Querying the Semantic Web: An Efficient Approach Using Relational Databases",',
#    ('li', 'ol')),
#   ('LAP Lambert Academic Publishing', ('a', 'li', 'ol')),
#   (',', ('li', 'ol')),
#   ('ISBN', ('a', 'li', 'ol')),
#   ('978-3-8383-0264-5', ('a', 'li', 'ol')),
#   (', 2009.', ('li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Victoria Shannon (June 26, 2006).', ('cite', 'li', 'ol')),
#   ('"A \'more revolutionary\' Web"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('International Herald Tribune', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('May 24,', ('cite', 'li', 'ol')),
#   ('2006.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('James Williams.', ('cite', 'li', 'ol')),
#   ('"Introducing The Concept Of Web 3.0"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('Tweak And Trick', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('10 January', ('cite', 'li', 'ol')),
#   ('2017.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Matthew Hodgson (9 October 2016).', ('cite', 'li', 'ol')),
#   ('"A decentralized web would give power back to the people online"',
#    ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('TechCrunch', ('cite', 'i', 'li', 'ol')),
#   ('. AOL Inc. Retrieved', ('cite', 'li', 'ol')),
#   ('1 December', ('cite', 'li', 'ol')),
#   ('2016.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Lukasiewicz, Thomas; Umberto Straccia (2008).', ('cite', 'li', 'ol')),
#   ('"Managing uncertainty and vagueness in description logics for the Semantic Web"',
#    ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('Web Semantics: Science, Services and Agents on the World Wide Web',
#    ('cite', 'i', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('6', ('b', 'cite', 'li', 'ol')),
#   ('(4): 291–308.', ('cite', 'li', 'ol')),
#   ('doi', ('a', 'cite', 'li', 'ol')),
#   (':', ('cite', 'li', 'ol')),
#   ('10.1016/j.websem.2008.04.001', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('"Semantic Web Standards"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('www.w3.org', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('14 April', ('cite', 'li', 'ol')),
#   ('2018.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('"OWL Web Ontology Language Overview"', ('a', 'cite', 'li', 'ol')),
#   ('. World Wide Web Consortium (W3C). February 10, 2004. Retrieved',
#    ('cite', 'li', 'ol')),
#   ('November 26,', ('cite', 'li', 'ol')),
#   ('2011.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('"Resource Description Framework (RDF)"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('World Wide Web Consortium', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Allemang, D.; Hendler, J. (2011). "RDF –The basis of the Semantic Web".',
#    ('cite', 'li', 'ol')),
#   ('Semantic Web for the Working Ontologist', ('cite', 'i', 'li', 'ol')),
#   ('(2nd ed.). Morgan Kaufmann.', ('cite', 'li', 'ol')),
#   ('doi', ('a', 'cite', 'li', 'ol')),
#   (':', ('cite', 'li', 'ol')),
#   ('10.1016/B978-0-12-385965-5.10003-2', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('ISBN', ('a', 'cite', 'li', 'ol')),
#   ('978-0-12-385965-5', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Sikos, Leslie F. (2015).', ('cite', 'li', 'ol')),
#   ('Mastering Structured Data on the Semantic Web: From HTML5 Microdata to Linked Open Data',
#    ('cite', 'i', 'li', 'ol')),
#   ('. Apress. p. 23.', ('cite', 'li', 'ol')),
#   ('ISBN', ('a', 'cite', 'li', 'ol')),
#   ('1484210492', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Omar Alonso', ('a', 'li', 'ol')),
#   ('and', ('li', 'ol')),
#   ('Hugo Zaragoza', ('a', 'li', 'ol')),
#   ('. 2008. Exploiting semantic annotations in information retrieval:',
#    ('li', 'ol')),
#   ('ESAIR', ('a', 'li', 'ol')),
#   ("'08. SIGIR Forum 42, 1 (June 2008), 55–58. DOI=", ('li', 'ol')),
#   ('https://dx.doi.org/10.1145/1394251.1394262', ('a', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Jaap Kamps', ('a', 'li', 'ol')),
#   (',', ('li', 'ol')),
#   ('Jussi Karlgren', ('a', 'li', 'ol')),
#   (', and', ('li', 'ol')),
#   ('Ralf Schenkel', ('a', 'li', 'ol')),
#   ('. 2011. Report on the third workshop on exploiting semantic annotations in information retrieval (ESAIR). SIGIR Forum 45, 1 (May 2011), 33–41. DOI=',
#    ('li', 'ol')),
#   ('https://dx.doi.org/10.1145/1988852.1988858', ('a', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Jaap Kamps', ('a', 'li', 'ol')),
#   (',', ('li', 'ol')),
#   ('Jussi Karlgren', ('a', 'li', 'ol')),
#   (',', ('li', 'ol')),
#   ('Peter Mika', ('a', 'li', 'ol')),
#   (', and', ('li', 'ol')),
#   ('Vanessa Murdock', ('a', 'li', 'ol')),
#   ('. 2012. Fifth workshop on exploiting semantic annotations in information retrieval:',
#    ('li', 'ol')),
#   ('ESAIR', ('a', 'li', 'ol')),
#   ("12). In Proceedings of the 21st ACM international conference on Information and knowledge management (CIKM '12). ACM, New York, NY, USA, 2772-2773. DOI=",
#    ('i', 'li', 'ol')),
#   ('https://dx.doi.org/10.1145/2396761.2398761', ('a', 'i', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Omar Alonso', ('a', 'li', 'ol')),
#   (',', ('li', 'ol')),
#   ('Jaap Kamps', ('a', 'li', 'ol')),
#   (', and', ('li', 'ol')),
#   ('Jussi Karlgren', ('a', 'li', 'ol')),
#   ('. 2015. Report on the Seventh Workshop on Exploiting Semantic Annotations in Information Retrieval (',
#    ('li', 'ol')),
#   ('ESAIR', ('a', 'li', 'ol')),
#   ("'14). SIGIR Forum 49, 1 (June 2015), 27–34. DOI=", ('li', 'ol')),
#   ('https://dx.doi.org/10.1145/2795403.2795412', ('a', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Kuriakose, John (September 2009).', ('cite', 'li', 'ol')),
#   ('"Understanding and Adopting Semantic Web Technology"',
#    ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('Cutter IT Journal', ('cite', 'i', 'li', 'ol')),
#   ('. CUTTER INFORMATION CORP.', ('cite', 'li', 'ol')),
#   ('22', ('b', 'cite', 'li', 'ol')),
#   ('(9): 10–18.', ('cite', 'li', 'ol')),
#   ('^', ('li', 'ol')),
#   ('a', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('b', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('c', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('Marshall, Catherine C.; Shipman, Frank M. (2003).', ('cite', 'li', 'ol')),
#   ('Which semantic web?', ('a', 'cite', 'i', 'li', 'ol')),
#   ('(PDF)', ('cite', 'li', 'ol')),
#   ('. Proc. ACM Conf. on Hypertext and Hypermedia. pp. 57–66.',
#    ('cite', 'li', 'ol')),
#   ('^', ('li', 'ol')),
#   ('a', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('b', ('a', 'b', 'i', 'li', 'ol', 'sup')),
#   ('Ivan Herman (2007).', ('cite', 'li', 'ol')),
#   ('State of the Semantic Web', ('a', 'cite', 'i', 'li', 'ol')),
#   ('(PDF)', ('cite', 'li', 'ol')),
#   ('. Semantic Days 2007. Retrieved', ('cite', 'li', 'ol')),
#   ('July 26,', ('cite', 'li', 'ol')),
#   ('2007.', ('cite', 'li', 'ol')),
#   ('Gärdenfors, Peter (2004).', ('cite', 'li', 'ol')),
#   ('How to make the Semantic Web more semantic', ('cite', 'i', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('Formal Ontology in Information Systems: proceedings of the third international conference (FOIS-2004)',
#    ('cite', 'i', 'li', 'ol')),
#   ('. IOS Press. pp. 17–34.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Honkela, Timo; Könönen, Ville; Lindh-Knuutila, Tiina; Paukkeri, Mari-Sanna (2008).',
#    ('cite', 'li', 'ol')),
#   ('"Simulating processes of concept formation and communication"',
#    ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('Journal of Economic Methodology', ('cite', 'i', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('"Policy Aware Web Project"', ('a', 'cite', 'li', 'ol')),
#   ('. Policyawareweb.org. Retrieved', ('cite', 'li', 'ol')),
#   ('2013-06-14', ('cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Buffa, Michel; Dehors, Sylvain; Faron-Zucker, Catherine; Sander, Peter (2005).',
#    ('cite', 'li', 'ol')),
#   ('"Towards a Corporate Semantic Web Approach in Designing Learning Systems: Review of the Trial Solutioins Project"',
#    ('a', 'cite', 'li', 'ol')),
#   ('(PDF)', ('cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('International Workshop on Applications of Semantic Web Technologies for E-Learning',
#    ('cite', 'i', 'li', 'ol')),
#   ('. Amsterdam, Holland. pp. 73–76.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('"Corporate Semantic Web - Home"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('www.corporate-semantic-web.de', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('14 April', ('cite', 'li', 'ol')),
#   ('2018.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Hinze, Annika; Heese, Ralf; Luczak-Rösch, Markus; Paschke, Adrian (2012).',
#    ('cite', 'li', 'ol')),
#   ('"Semantic Enrichment by Non-Experts: Usability of Manual Annotation Tools"',
#    ('a', 'cite', 'li', 'ol')),
#   ('(PDF)', ('cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ("ISWC'12 - Proceedings of the 11th international conference on The Semantic Web",
#    ('cite', 'i', 'li', 'ol')),
#   ('. Boston, USA. pp. 165–181.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('Mathieson, S. A. (6 April 2006).', ('cite', 'li', 'ol')),
#   ('"Spread the word, and join it up"', ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('the Guardian', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('14 April', ('cite', 'li', 'ol')),
#   ('2018.', ('cite', 'li', 'ol')),
#   ('^', ('a', 'b', 'li', 'ol')),
#   ('"The Semantic Web, Collective Intelligence and Hyperdata"',
#    ('a', 'cite', 'li', 'ol')),
#   ('.', ('cite', 'li', 'ol')),
#   ('This Blog has Moved to NovaSpivack.com', ('cite', 'i', 'li', 'ol')),
#   ('. Retrieved', ('cite', 'li', 'ol')),
#   ('14 April', ('cite', 'li', 'ol')),
#   ('2018.', ('cite', 'li', 'ol'))),
#  (('Further reading[', ('h2',)),
#   ('edit', ('a', 'h2')),
#   (']', ('h2',)),
#   ('Liyang Yu (December 14, 2014).', ('cite', 'li', 'ul')),
#   ("A Developer's Guide to the Semantic Web,2nd ed",
#    ('a', 'cite', 'i', 'li', 'ul')),
#   ('. Springer.', ('cite', 'li', 'ul')),
#   ('ISBN', ('a', 'cite', 'li', 'ul')),
#   ('978-3-662-43796-4', ('a', 'cite', 'li', 'ul')),
#   ('.', ('cite', 'li', 'ul')),
#   ("Aaron Swartz's A Programmable Web: An unfinished Work", ('a', 'li', 'ul')),
#   ("donated by Morgan & Claypool Publishers after Aaron Swartz's death in January 2013.",
#    ('li', 'ul')),
#   ('Grigoris Antoniou,', ('cite', 'li', 'ul')),
#   ('Frank van Harmelen', ('a', 'cite', 'li', 'ul')),
#   ('(March 31, 2008).', ('cite', 'li', 'ul')),
#   ('A Semantic Web Primer, 2nd Edition', ('cite', 'i', 'li', 'ul')),
#   ('. The', ('cite', 'li', 'ul')),
#   ('MIT Press', ('a', 'cite', 'li', 'ul')),
#   ('.', ('cite', 'li', 'ul')),
#   ('ISBN', ('a', 'cite', 'li', 'ul')),
#   ('0-262-01242-1', ('a', 'cite', 'li', 'ul')),
#   ('.', ('cite', 'li', 'ul')),
#   ('Dean Allemang', ('a', 'cite', 'li', 'ul')),
#   (',', ('cite', 'li', 'ul')),
#   ('James Hendler', ('a', 'cite', 'li', 'ul')),
#   ('(May 9, 2008).', ('cite', 'li', 'ul')),
#   ('Semantic Web for the Working Ontologist: Effective Modeling in RDFS and OWL',
#    ('cite', 'i', 'li', 'ul')),
#   ('. Morgan Kaufmann.', ('cite', 'li', 'ul')),
#   ('ISBN', ('a', 'cite', 'li', 'ul')),
#   ('978-0-12-373556-0', ('a', 'cite', 'li', 'ul')),
#   ('.', ('cite', 'li', 'ul')),
#   ('Pascal Hitzler; Markus Krötzsch; Sebastian Rudolph (August 25, 2009).',
#    ('cite', 'li', 'ul')),
#   ('Foundations of Semantic Web Technologies', ('a', 'cite', 'i', 'li', 'ul')),
#   ('. CRCPress.', ('cite', 'li', 'ul')),
#   ('ISBN', ('a', 'cite', 'li', 'ul')),
#   ('1-4200-9050-X', ('a', 'cite', 'li', 'ul')),
#   ('.', ('cite', 'li', 'ul')),
#   ('Thomas B. Passin (March 1, 2004).', ('cite', 'li', 'ul')),
#   ("Explorer's Guide to the Semantic Web", ('cite', 'i', 'li', 'ul')),
#   ('. Manning Publications.', ('cite', 'li', 'ul')),
#   ('ISBN', ('a', 'cite', 'li', 'ul')),
#   ('1-932394-20-6', ('a', 'cite', 'li', 'ul')),
#   ('.', ('cite', 'li', 'ul')),
#   ('Jeffrey T. Pollock (March 23, 2009).', ('cite', 'li', 'ul')),
#   ('Semantic Web For Dummies', ('a', 'cite', 'i', 'li', 'ul')),
#   ('. For Dummies.', ('cite', 'li', 'ul')),
#   ('ISBN', ('a', 'cite', 'li', 'ul')),
#   ('0-470-39679-2', ('a', 'cite', 'li', 'ul')),
#   ('.', ('cite', 'li', 'ul'))),
#  (('External links[', ('h2',)), ('edit', ('a', 'h2')), (']', ('h2',)))]

# %%
for paragraph in parser._article.main_text:
    break

# %%
paragraph
# Out:
# (('The', None),
#  ('Semantic Web', ('b',)),
#  ('is an extension of the', None),
#  ('World Wide Web', ('a',)),
#  ('through standards by the', None),
#  ('World Wide Web Consortium', ('a',)),
#  ('(W3C).', None),
#  ('[1]', ('a', 'sup')),
#  ('The standards promote common data formats and exchange protocols on the Web, most fundamentally the',
#   None),
#  ('Resource Description Framework', ('a',)),
#  ('(RDF). According to the W3C, "The Semantic Web provides a common framework that allows data to be shared and reused across application, enterprise, and community boundaries".',
#   None),
#  ('[2]', ('a', 'sup')),
#  ('The Semantic Web is therefore regarded as an integrator across different content, information applications and systems.',
#   None))

# %%
# parser contains the ODM (parser.document) which is all that is needed to run summarizer
# Summarizer can be instantiated once and used for multiple different ODMs

# %%
parser.document
# Out:
# <DOM with 57 paragraphs>

# %%
parser._article.main_text[0]
# Out:
# (('The', None),
#  ('Semantic Web', ('b',)),
#  ('is an extension of the', None),
#  ('World Wide Web', ('a',)),
#  ('through standards by the', None),
#  ('World Wide Web Consortium', ('a',)),
#  ('(W3C).', None),
#  ('[1]', ('a', 'sup')),
#  ('The standards promote common data formats and exchange protocols on the Web, most fundamentally the',
#   None),
#  ('Resource Description Framework', ('a',)),
#  ('(RDF). According to the W3C, "The Semantic Web provides a common framework that allows data to be shared and reused across application, enterprise, and community boundaries".',
#   None),
#  ('[2]', ('a', 'sup')),
#  ('The Semantic Web is therefore regarded as an integrator across different content, information applications and systems.',
#   None))

# %%
parser.document.paragraphs[0].sentences
# should be smart enough to remove obvious footer hyperlinks (i.e. if only symbols and numbers within string.split(' ') and is ahref)
# should also be able to auto-extract keywords if they are in bold (this would be format dependent requiring a data entry)
# Out:
# (<Sentence: The Semantic Web is an extension of the World Wide Web through standards by the World Wide Web Consortium (W3C).>,
#  <Sentence: [1] The standards promote common data formats and exchange protocols on the Web, most fundamentally the Resource Description Framework (RDF).>,
#  <Sentence: According to the W3C, "The Semantic Web provides a common framework that allows data to be shared and reused across application, enterprise, and community boundaries".>,
#  <Sentence: [2] The Semantic Web is therefore regarded as an integrator across different content, information applications and systems.>)

# %%
import io

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage


def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    with open(path, 'rb') as fp:
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        password = ""
        maxpages = 0
        caching = True
        pagenos = set()

        for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages,
                                      password=password,
                                      caching=caching,
                                      check_extractable=True):
            interpreter.process_page(page)

        text = retstr.getvalue()
        
    device.close()
    retstr.close()
    return text

# %%
def find_first_nonspace(string, char=' '):
    for ii, letter in enumerate(string):
        if letter!=char:
            return ii
        
def in_ignores(char):
    ignore_chars = {'\x0c', ''}  # pdf print next sheet flag
    return not (char in ignore_chars)


bullets = {u"\u2022"}
punctuation = set(list('.?!'))

sentences = convert_pdf_to_txt("pdf-sample.pdf").split('\n')
prx_sentences = []
cont_sent = ''
for si, sentence in enumerate(sentences):
    # Skip any empty sentences to be removed later
    if len(sentence)>0:
        if sentence[0] in bullets:
            start_ind = find_first_nonspace(sentence[1:], ' ')+1
            sentence = sentence[start_ind:]

        # Sentence ending in punctuation logic
        if sentence[-1] in punctuation and cont_sent:
            #print(cont_sent+' '+sentence+'\n')
            prx_sentences.append(cont_sent+' '+sentence)
            cont_sent = ''
        elif sentence[-1] in punctuation:
            prx_sentences.append(sentence)
            cont_sent = ''
        elif cont_sent:
            cont_sent += ' ' + sentence
        elif si == len(sentences)-1:
            prx_sentences.append(sentence)
        else:
            cont_sent = sentence
        
# Remove any sentences with weird unicode issues
prx_sentences = list(filter(in_ignores, prx_sentences))
for si, sentence in enumerate(prx_sentences):
    print(si, sentence, '\n')
# Out:
# 0 Adobe Acrobat PDF Files Adobe® Portable Document Format (PDF) is a universal file format that preserves all of the fonts, formatting, colours and graphics of any source document, regardless of the application and platform used to create it.
#
# 1 Adobe PDF is an ideal format for electronic document distribution as it overcomes the problems commonly encountered with electronic file sharing.
#
# 2 Anyone, anywhere can open a PDF file. All you need is the free Adobe Acrobat Reader. Recipients of other file formats sometimes can't open files because they don't have the applications used to create the documents.
#
# 3 PDF files always print correctly on any printing device.
#
# 4 PDF  files  always  display  exactly  as  created,  regardless  of  fonts,  software,  and operating systems. Fonts, and graphics are not lost due to platform, software, and version incompatibilities.
#
# 5 The  free  Acrobat  Reader  is  easy  to  download  and  can  be  freely  distributed  by anyone.
#
# 6 Compact  PDF  files  are  smaller  than  their  source  files  and  download  a page at a time for fast display on the Web.

# %%
from sumyplus.models.dom import Sentence, Paragraph, ObjectDocumentModel

# %%
token = Tokenizer(LANGUAGE)
#base_docparse = DocumentParser(token)

def create_odm(text, tokenizer):
    """  """
    paragraphs = []
    sentences = []
    for sentence in text:
        sentences.append(Sentence(sentence, tokenizer))
    
    paragraphs.append(Paragraph(sentences))

    return ObjectDocumentModel(paragraphs)

dom = create_odm(prx_sentences, token)
dom
# Out:
# <DOM with 1 paragraphs>

# %%
dom.__dict__
# Out:
# {'_paragraphs': (<Paragraph with 0 headings & 7 sentences>,)}

# %%
for sentence in summarizer(dom, 3):
    print(sentence, '\n')
# Out:
# Adobe Acrobat PDF Files Adobe® Portable Document Format (PDF) is a universal file format that preserves all of the fonts, formatting, colours and graphics of any source document, regardless of the application and platform used to create it.
#
# PDF  files  always  display  exactly  as  created,  regardless  of  fonts,  software,  and operating systems. Fonts, and graphics are not lost due to platform, software, and version incompatibilities.
#
# The  free  Acrobat  Reader  is  easy  to  download  and  can  be  freely  distributed  by anyone.

# %%
dom.sentences
# Out:
# (<Sentence: Adobe Acrobat PDF Files Adobe® Portable Document Format (PDF) is a universal file format that preserves all of the fonts, formatting, colours and graphics of any source document, regardless of the application and platform used to create it.>,
#  <Sentence: Adobe PDF is an ideal format for electronic document distribution as it overcomes the problems commonly encountered with electronic file sharing.>,
#  <Sentence: Anyone, anywhere can open a PDF file. All you need is the free Adobe Acrobat Reader. Recipients of other file formats sometimes can't open files because they don't have the applications used to create the documents.>,
#  <Sentence: PDF files always print correctly on any printing device.>,
#  <Sentence: PDF  files  always  display  exactly  as  created,  regardless  of  fonts,  software,  and operating systems. Fonts, and graphics are not lost due to platform, software, and version incompatibilities.>,
#  <Sentence: The  free  Acrobat  Reader  is  easy  to  download  and  can  be  freely  distributed  by anyone.>,
#  <Sentence: Compact  PDF  files  are  smaller  than  their  source  files  and  download  a page at a time for fast display on the Web.>)
